# %% [markdown]
# <a href="https://colab.research.google.com/github/shahriarhossainsaad/Git_HuB/blob/main/23101192SJF(NonPreemptive).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Process:
    def __init__(self, pid, at, bt):
        self.pid = pid
        self.at = at
        self.bt = bt
        self.rt = bt
        self.ct = 0
        self.tat = 0
        self.wt = 0


n = int(input("Enter the number of processes: "))
p = []

for i in range(n):
    at = int(input(f"P{i+1} Arrival Time: "))
    bt = int(input(f"P{i+1} Burst Time: "))
    p.append(Process(f"P{i+1}", at ,bt))

time = 0
done = 0

while done < n :
    ready = [x for x in p if x.at <= time and x.rt > 0]

    if not ready :
        time += 1
        continue

    cur = min(ready, key = lambda x : x.rt)
    cur.rt -= 1
    time += 1

    if cur.rt == 0 :
        cur.ct = time
        cur.tat = cur.ct - cur.at
        cur.wt = cur.tat - cur.bt
        done += 1

# These print statements should execute once, after the while loop finishes.
print("\nPID\tAT\tBT\tCT\tTAT\tWT")
for x in p :
    print(x.pid, x.at, x.bt, x.ct, x.tat, x.wt, sep="\t")

print("\nAverage TAT: ", sum(x.tat for x in p)/n)
print("Average WT: ", sum(x.wt for x in p)/n)
# Out:
# Enter the number of processes: 6
# P1 Arrival Time: 3
# P1 Burst Time: 1
# P2 Arrival Time: 2
# P2 Burst Time: 4
# P3 Arrival Time: 3
# P3 Burst Time: 6
# P4 Arrival Time: 1
# P4 Burst Time: 3
# P5 Arrival Time: 4
# P5 Burst Time: 2
# P6 Arrival Time: 6
# P6 Burst Time: 1
#
# PID	AT	BT	CT	TAT	WT
# P1	3	1	4	1	0
# P2	2	4	12	10	6
# P3	3	6	18	15	9
# P4	1	3	5	4	1
# P5	4	2	7	3	1
# P6	6	1	8	2	1
#
# Average TAT:  5.833333333333333
# Average WT:  3.0
