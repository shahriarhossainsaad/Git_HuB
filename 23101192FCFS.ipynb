# %% [markdown]
# <a href="https://colab.research.google.com/github/shahriarhossainsaad/Git_HuB/blob/main/23101192FCFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
process = [
    ("p1", 3, 3),
    ("p2", 2, 1),
    ("p3", 5, 2),
    ("p4", 0, 3),
    ("p5", 1, 2)
]

process.sort(key=lambda x: x[1])
time = 0
total_wt = 0
total_tat = 0

print("Process AT BT CT TAT WT")

for p, at, bt in process:

  if time < at:
    time = at

  time = time + bt
  ct = time

  tat = ct - at
  wt = tat - bt

  total_tat = total_tat + tat
  total_wt = total_wt + wt

  print(p, at, bt, ct, tat, wt)


  n = len(process)
  print ("Average TAT =" , total_tat/n)
  print("Average WT =", total_wt/n)
# Out:
# Process AT BT CT TAT WT
# p4 0 3 3 3 0
# Average TAT = 0.6
# Average WT = 0.0
# p5 1 2 5 4 2
# Average TAT = 1.4
# Average WT = 0.4
# p2 2 1 6 4 3
# Average TAT = 2.2
# Average WT = 1.0
# p1 3 3 9 6 3
# Average TAT = 3.4
# Average WT = 1.6
# p3 5 2 11 6 4
# Average TAT = 4.6
# Average WT = 2.4
